# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from fcmeans import FCM
#from pyclustertend import ivat
from PGM_Func import MakeDataSet, LoadDataSets

datasets = LoadDataSets(os.getcwd(), '.PGM')

# %%
def fuzzy_cluster(data, clusters, fuzzifier):
    data_df = pd.DataFrame(np.rot90(data), columns=["feature1", "feature2"])
    
    model = FCM(n_clusters = clusters, m=fuzzifier) #m is the fuzzifier
    model.fit(np.rot90(data))
    centers = model.centers
    #print("The centers are:  ", centers)
    err = model.error
    #print("The Error is:  ", err)

    labels = model.predict(np.rot90(data))
    data_df['Cluster FCM'] = labels

    x = data_df['feature1']
    y = data_df['feature2']
    label = data_df["Cluster FCM"]

    fig = plt.figure(figsize=(5,4))
    plt.scatter(x, y, c=label)

    #return labels

# %% [markdown]
# From VAT and iVAT this is how many clusters were indicated: <br>
# Dataset 1 - 3 or 4      <br>
# Dataset 2 - 4           <br>
# Dataset 3 - 2           <br>
# Dataset 4 - ?           <br>
# Dataset 5 - 2 or 3      <br>
# Dataset 6 - 3 or 4      <br>
# Dataset 7 - 2           <br>
# Dataset 8 - 2           <br>
# Dataset 9 - 2 or 3      <br>
# Dataset 10 - 2          <br>
# Dataset 11 - 2          <br>
# Dataset 12 - 2, 3, or 4 <br>

# %%
#fuzzy_cluster function paramaters - data, number of clusters, fuzzifier
fuzzy_cluster(datasets[1], 3, 1.7)
fuzzy_cluster(datasets[1], 4, 1.5)

# %%
fuzzy_cluster(datasets[2], 4, 1.5)

# %%
fuzzy_cluster(datasets[3], 2, 1.7)

# %%
fuzzy_cluster(datasets[4], 2, 1.7)
fuzzy_cluster(datasets[4], 3, 1.7)
fuzzy_cluster(datasets[4], 4, 1.7)

# %%
fuzzy_cluster(datasets[5], 2, 1.7)
fuzzy_cluster(datasets[5], 3, 1.7)

# %%
fuzzy_cluster(datasets[6], 3, 2.0)
fuzzy_cluster(datasets[6], 4, 1.7)
fuzzy_cluster(datasets[6], 5, 1.7)

# %%
fuzzy_cluster(datasets[7], 2, 1.7)

# %%
fuzzy_cluster(datasets[8], 2, 1.7)
fuzzy_cluster(datasets[8], 2, 2.5)

# %%
fuzzy_cluster(datasets[9], 2, 1.7)
fuzzy_cluster(datasets[9], 3, 1.7)

# %%
fuzzy_cluster(datasets[10], 2, 1.7)

# %%
fuzzy_cluster(datasets[11], 2, 1.7)

# %%
fuzzy_cluster(datasets[12], 2, 1.7)
fuzzy_cluster(datasets[12], 4, 1.7)

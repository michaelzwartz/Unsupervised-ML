# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from fcmeans import FCM
from sklearn import metrics
from sklearn.metrics import pairwise_distances
from sklearn.metrics import davies_bouldin_score
from PGM_Func import MakeDataSet, LoadDataSets


datasets = LoadDataSets(os.getcwd(), '.PGM')

# %%
#fuzzy_cluster function paramaters - data, number of clusters, fuzzifier

def fuzzy_cluster(data, clusters, fuzzifier):
    data_df = pd.DataFrame(np.rot90(data), columns=["feature1", "feature2"])
    
    model = FCM(n_clusters = clusters, m=fuzzifier) #m is the fuzzifier
    model.fit(np.rot90(data))
    centers = model.centers
    #print("The centers are:  ", centers)
    err = model.error
    #print("The Error is:  ", err)

    labels = model.predict(np.rot90(data))
    #data_df['Cluster FCM'] = labels

    x = data_df['feature1']
    y = data_df['feature2']
    #label = data_df["Cluster FCM"]

    #Plot the data with different color clusters
    fig = plt.figure(figsize=(5,4))
    plt.scatter(x, y, c=labels)

    return data_df, labels

# %%
#create dataframe to track silhouette scores for clusters
d = {'Dataset': [], 'Cluster Number': [], 'Silhouette Score': [], 
     'Davies-Bouldin': [], 'Calinski-Harabasz': []}
validity_scores = pd.DataFrame(data=d)

# %%
#create a list of fuzzy c-means files
name = ['X1_3', 'X1_4']

#create a variable for the dataset number
dataset_num = 1

#variable for the minimum number of clusters
num_clusters = 3

#for loop to run silhouette score for all clusters for this dataset
for data in name: 
    data, labels = fuzzy_cluster(datasets[dataset_num], num_clusters, 1.7)
    validity_scores.loc[len(validity_scores.index)] = [dataset_num, num_clusters,
        metrics.silhouette_score(data, labels, metric='euclidean'), metrics.davies_bouldin_score(data, labels),
        metrics.calinski_harabasz_score(data, labels)]
    num_clusters = num_clusters + 1

validity_scores.head()
# Out:
#    Dataset  Cluster Number  Silhouette Score  Davies-Bouldin  \
# 0      1.0             3.0          0.544014        0.664025
# 1      1.0             4.0          0.576003        0.594946
#
#    Calinski-Harabasz
# 0        4852.441646
# 1        5744.133525

# %%
name = ['X2_4']
dataset_num = 2
num_clusters = 4

for data in name: 
    data, labels = fuzzy_cluster(datasets[dataset_num], num_clusters, 1.7)
    validity_scores.loc[len(validity_scores.index)] = [dataset_num, num_clusters,
        metrics.silhouette_score(data, labels, metric='euclidean'), metrics.davies_bouldin_score(data, labels),
        metrics.calinski_harabasz_score(data, labels)]
    num_clusters = num_clusters + 1

validity_scores.head()
# Out:
#    Dataset  Cluster Number  Silhouette Score  Davies-Bouldin  \
# 0      1.0             3.0          0.544014        0.664025
# 1      1.0             4.0          0.576003        0.594946
# 2      2.0             4.0          0.601187        0.515435
#
#    Calinski-Harabasz
# 0        4852.441646
# 1        5744.133525
# 2        3968.446730

# %%
name = ['X3_2']
dataset_num = 3
num_clusters = 2

for data in name: 
    data, labels = fuzzy_cluster(datasets[dataset_num], num_clusters, 1.7)
    validity_scores.loc[len(validity_scores.index)] = [dataset_num, num_clusters,
        metrics.silhouette_score(data, labels, metric='euclidean'), metrics.davies_bouldin_score(data, labels),
        metrics.calinski_harabasz_score(data, labels)]
    num_clusters = num_clusters + 1

validity_scores.head()

# %%
name = ['X4_2', 'X4_3', 'X4_5']
dataset_num = 4
num_clusters = 2

for data in name: 
    data, labels = fuzzy_cluster(datasets[dataset_num], num_clusters, 1.7)
    validity_scores.loc[len(validity_scores.index)] = [dataset_num, num_clusters,
        metrics.silhouette_score(data, labels, metric='euclidean'), metrics.davies_bouldin_score(data, labels),
        metrics.calinski_harabasz_score(data, labels)]
    num_clusters = num_clusters + 1

validity_scores.head()
# Out:
#    Dataset  Cluster Number  Silhouette Score  Davies-Bouldin  \
# 0      1.0             3.0          0.544014        0.664025
# 1      1.0             4.0          0.576003        0.594946
# 2      2.0             4.0          0.601187        0.515435
# 3      4.0             2.0          0.365085        1.133396
# 4      4.0             3.0          0.388852        0.832669
#
#    Calinski-Harabasz
# 0        4852.441646
# 1        5744.133525
# 2        3968.446730
# 3         427.614550
# 4         525.278307

# %%
name = ['X5_2', 'X5_3']
dataset_num = 5
num_clusters = 2

for data in name: 
    data, labels = fuzzy_cluster(datasets[dataset_num], num_clusters, 1.7)
    validity_scores.loc[len(validity_scores.index)] = [dataset_num, num_clusters,
        metrics.silhouette_score(data, labels, metric='euclidean'), metrics.davies_bouldin_score(data, labels),
        metrics.calinski_harabasz_score(data, labels)]
    num_clusters = num_clusters + 1

validity_scores.head()
# Out:
#    Dataset  Cluster Number  Silhouette Score  Davies-Bouldin  \
# 0      1.0             3.0          0.544014        0.664025
# 1      1.0             4.0          0.576003        0.594946
# 2      2.0             4.0          0.601187        0.515435
# 3      4.0             2.0          0.365085        1.133396
# 4      4.0             3.0          0.388852        0.832669
#
#    Calinski-Harabasz
# 0        4852.441646
# 1        5744.133525
# 2        3968.446730
# 3         427.614550
# 4         525.278307

# %%
name = ['X6_3', 'X6_4', 'X6_5']
dataset_num = 6
num_clusters = 3

for data in name: 
    data, labels = fuzzy_cluster(datasets[dataset_num], num_clusters, 1.7)
    validity_scores.loc[len(validity_scores.index)] = [dataset_num, num_clusters,
        metrics.silhouette_score(data, labels, metric='euclidean'), metrics.davies_bouldin_score(data, labels),
        metrics.calinski_harabasz_score(data, labels)]
    num_clusters = num_clusters + 1

validity_scores.head()
# Out:
#    Dataset  Cluster Number  Silhouette Score  Davies-Bouldin  \
# 0      1.0             3.0          0.544014        0.664025
# 1      1.0             4.0          0.576003        0.594946
# 2      2.0             4.0          0.601187        0.515435
# 3      4.0             2.0          0.365085        1.133396
# 4      4.0             3.0          0.388852        0.832669
#
#    Calinski-Harabasz
# 0        4852.441646
# 1        5744.133525
# 2        3968.446730
# 3         427.614550
# 4         525.278307

# %%
name = ['X4_2']
dataset_num = 7
num_clusters = 2

for data in name: 
    data, labels = fuzzy_cluster(datasets[dataset_num], num_clusters, 1.7)
    validity_scores.loc[len(validity_scores.index)] = [dataset_num, num_clusters,
        metrics.silhouette_score(data, labels, metric='euclidean'), metrics.davies_bouldin_score(data, labels),
        metrics.calinski_harabasz_score(data, labels)]
    num_clusters = num_clusters + 1

validity_scores.head()
# Out:
#    Dataset  Cluster Number  Silhouette Score  Davies-Bouldin  \
# 0      1.0             3.0          0.544014        0.664025
# 1      1.0             4.0          0.576003        0.594946
# 2      2.0             4.0          0.601187        0.515435
# 3      4.0             2.0          0.365085        1.133396
# 4      4.0             3.0          0.388852        0.832669
#
#    Calinski-Harabasz
# 0        4852.441646
# 1        5744.133525
# 2        3968.446730
# 3         427.614550
# 4         525.278307

# %%
name = ['X8_2']
dataset_num = 8
num_clusters = 2

for data in name: 
    data, labels = fuzzy_cluster(datasets[dataset_num], num_clusters, 1.7)
    validity_scores.loc[len(validity_scores.index)] = [dataset_num, num_clusters,
        metrics.silhouette_score(data, labels, metric='euclidean'), metrics.davies_bouldin_score(data, labels),
        metrics.calinski_harabasz_score(data, labels)]
    num_clusters = num_clusters + 1

validity_scores.head()
# Out:
#    Dataset  Cluster Number  Silhouette Score  Davies-Bouldin  \
# 0      1.0             3.0          0.544014        0.664025
# 1      1.0             4.0          0.576003        0.594946
# 2      2.0             4.0          0.601187        0.515435
# 3      4.0             2.0          0.365085        1.133396
# 4      4.0             3.0          0.388852        0.832669
#
#    Calinski-Harabasz
# 0        4852.441646
# 1        5744.133525
# 2        3968.446730
# 3         427.614550
# 4         525.278307

# %%
name = ['X9_2', 'X9_3']
dataset_num = 9
num_clusters = 2

for data in name: 
    data, labels = fuzzy_cluster(datasets[dataset_num], num_clusters, 1.7)
    validity_scores.loc[len(validity_scores.index)] = [dataset_num, num_clusters,
        metrics.silhouette_score(data, labels, metric='euclidean'), metrics.davies_bouldin_score(data, labels),
        metrics.calinski_harabasz_score(data, labels)]
    num_clusters = num_clusters + 1

validity_scores.head()
# Out:
#    Dataset  Cluster Number  Silhouette Score  Davies-Bouldin  \
# 0      1.0             3.0          0.544014        0.664025
# 1      1.0             4.0          0.576003        0.594946
# 2      2.0             4.0          0.601187        0.515435
# 3      4.0             2.0          0.365085        1.133396
# 4      4.0             3.0          0.388852        0.832669
#
#    Calinski-Harabasz
# 0        4852.441646
# 1        5744.133525
# 2        3968.446730
# 3         427.614550
# 4         525.278307

# %%
name = ['X10_2']
dataset_num = 10
num_clusters = 2

for data in name: 
    data, labels = fuzzy_cluster(datasets[dataset_num], num_clusters, 1.7)
    validity_scores.loc[len(validity_scores.index)] = [dataset_num, num_clusters,
        metrics.silhouette_score(data, labels, metric='euclidean'), metrics.davies_bouldin_score(data, labels),
        metrics.calinski_harabasz_score(data, labels)]
    num_clusters = num_clusters + 1

validity_scores.head()
# Out:
#    Dataset  Cluster Number  Silhouette Score  Davies-Bouldin  \
# 0      1.0             3.0          0.544014        0.664025
# 1      1.0             4.0          0.576003        0.594946
# 2      2.0             4.0          0.601187        0.515435
# 3      4.0             2.0          0.365085        1.133396
# 4      4.0             3.0          0.388852        0.832669
#
#    Calinski-Harabasz
# 0        4852.441646
# 1        5744.133525
# 2        3968.446730
# 3         427.614550
# 4         525.278307

# %%
name = ['X11_2']
dataset_num = 11
num_clusters = 2

for data in name: 
    data, labels = fuzzy_cluster(datasets[dataset_num], num_clusters, 1.7)
    validity_scores.loc[len(validity_scores.index)] = [dataset_num, num_clusters,
        metrics.silhouette_score(data, labels, metric='euclidean'), metrics.davies_bouldin_score(data, labels),
        metrics.calinski_harabasz_score(data, labels)]
    num_clusters = num_clusters + 1

validity_scores.head()
# Out:
#    Dataset  Cluster Number  Silhouette Score  Davies-Bouldin  \
# 0      1.0             3.0          0.544014        0.664025
# 1      1.0             4.0          0.576003        0.594946
# 2      2.0             4.0          0.601187        0.515435
# 3      4.0             2.0          0.365085        1.133396
# 4      4.0             3.0          0.388852        0.832669
#
#    Calinski-Harabasz
# 0        4852.441646
# 1        5744.133525
# 2        3968.446730
# 3         427.614550
# 4         525.278307

# %%
name = ['X12_2', 'X12_3', 'X12_4']
dataset_num = 12
num_clusters = 2

for data in name: 
    data, labels = fuzzy_cluster(datasets[dataset_num], num_clusters, 1.7)
    validity_scores.loc[len(validity_scores.index)] = [dataset_num, num_clusters,
        metrics.silhouette_score(data, labels, metric='euclidean'), metrics.davies_bouldin_score(data, labels),
        metrics.calinski_harabasz_score(data, labels)]
    num_clusters = num_clusters + 1

validity_scores.head()
# Out:
#    Dataset  Cluster Number  Silhouette Score  Davies-Bouldin  \
# 0      1.0             3.0          0.544014        0.664025
# 1      1.0             4.0          0.576003        0.594946
# 2      2.0             4.0          0.601187        0.515435
# 3      4.0             2.0          0.365085        1.133396
# 4      4.0             3.0          0.388852        0.832669
#
#    Calinski-Harabasz
# 0        4852.441646
# 1        5744.133525
# 2        3968.446730
# 3         427.614550
# 4         525.278307

# %%
#print full table of validity scores
validity_scores
# Out:
#     Dataset  Cluster Number  Silhouette Score  Davies-Bouldin  \
# 0       1.0             3.0          0.544014        0.664025
# 1       1.0             4.0          0.576003        0.594946
# 2       2.0             4.0          0.601187        0.515435
# 3       4.0             2.0          0.365085        1.133396
# 4       4.0             3.0          0.388852        0.832669
# 5       4.0             4.0          0.408601        0.785141
# 6       5.0             2.0          0.662564        0.494492
# 7       5.0             3.0          0.576977        0.558371
# 8       6.0             3.0          0.379272        1.027562
# 9       6.0             4.0          0.326210        1.033647
# 10      6.0             5.0          0.380402        0.941458
# 11      7.0             2.0          0.581331        0.608608
# 12      8.0             2.0          0.351611        1.105721
# 13      9.0             2.0          0.602336        0.540247
# ...

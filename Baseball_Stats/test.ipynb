# %%
from get_data_bat import batStats_clean20

batStats_clean20.head()
# Out:
#       IDfg  Season             Name Team       Age       IBB        SO  \
# 3952     1    2006  Alfredo Amezaga  FLA  0.346154  0.033333  0.176744
# 2614     1    2007  Alfredo Amezaga  FLA  0.384615  0.000000  0.204651
# 1034     2    2002  Garret Anderson  ANA  0.423077  0.091667  0.334884
# 431      2    2003  Garret Anderson  ANA  0.461538  0.083333  0.348837
# 4361     2    2004  Garret Anderson  ANA  0.500000  0.050000  0.311628
#
#             SB        BU     BABIP  ...       CB%  O-Contact%      wGDP  \
# 3952  0.256410  0.191011  0.474104  ...  0.125000    0.693642  0.601852
# 2614  0.166667  0.202247  0.470120  ...  0.161765    0.725434  0.638889
# 1034  0.076923  0.011236  0.529880  ...  0.669118    0.417630  0.796296
# 431   0.076923  0.000000  0.597610  ...  0.625000    0.514451  0.601852
# 4361  0.025641  0.000000  0.633466  ...  0.492647    0.410405  0.694444
#
#          Oppo%      OBP+      SLG+    Pull%+    Soft%+    Hard%+     L-WAR
# ...
